# %% [markdown]
# <a href="https://colab.research.google.com/github/torres970823-cyber/code_a_toy_generation/blob/main/metoto_de_agregar_%2C_remover_um_valor_dentro_do_vetor%2C_e_usar_o_random_para_sortear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = "luyz"
idade = 32
altura = 1.73

print(aluno)
print(idade)
print(altura)



list_alunos = ["lucas", "lucas s3", "luana","elevin"]
list_altura = [ 1.50, 1.75, 1.89, 2.00]
list_idades = [20, 21, 23, 21]
# Out:
# luyz
# 32
# 1.73

# %%
list_alunos = ["lucas", "lucas s3", "luana","evelin"]
list_altura = [ 1.50, 1.75, 1.89, 2.00]
list_idades = [20, 21, 23, 21]

print(list_alunos[-1])
print(list_altura[-1])
print(list_idades[-1])
# Out:
# evelin
# 2.0
# 21

# %%
list_professores = ["felipe", "marcelo","luyz"]

print(f"os professores de 2025 são: [list_professores]")

print("em 2026 ,temos um novo professor e a lista vai ficar:")

novo_professor = input("informe o nome do novo professor:")

#para adicionar um novo valor fazemos
# chamar a lista e colocar o atributo append com o novo valor
#list.append ("novo valor")

list_professores.append(novo_professor)
print(list_professores)

#agora vamos remover um dos valores
#para remover usamos a ferramenta pop
#chamar a lista e colocar o atributo pop, com a posição do valor que queremos remover
#list.pop(index)
# quero remover o marcelo
list_professores.pop(1)
print(list_professores)
# Out:
# os professores de 2025 são: [list_professores]
# em 2026 ,temos um novo professor e a lista vai ficar:
# informe o nome do novo professor:anderson
# ['felipe', 'marcelo', 'luyz', 'anderson']
# ['felipe', 'luyz', 'anderson']

# %%
# @title Texto de título padrão
import random
#quando colocamos import random, osistema aprende a sortear valor

list_dado = [1,2,3,4,5,6]

sortear = random.choice(list_dado)
print(sortear)
# Out:
# 3

# %%
#jogo 1 - remover valor da lista
# temos a lista
list_pets = ["meg","duda","pandora","joy","garoa","mini","soneca","honda","lucky","bingo"
]

#desafio 1 sortear uma posição da lista dos pets
# usando o comando pop, remover a posição sorteada

#boa sorte;)

# %%
list_pets = ["meg","duda","pandora","joy",
             "garoa","mini","soneca","honda","lucky","bingo"
]

import random
sorteio = random.choice(list_pets)
print(sorteio)

resultado_do_sorteio = input("coloque o numero da posicao do pet ")
print(resultado_do_sorteio)

list_pets.pop(int(resultado_do_sorteio))


print(f"resultado da lista logo apos remover o pet:{list_pets}")
# Out:
# mini
# coloque o numero da posicao do pet 5
# 5
# resultado da lista logo apos remover o pet:['meg', 'duda', 'pandora', 'joy', 'garoa', 'soneca', 'honda', 'lucky', 'bingo']
